# %%
import pandas as pd
import os
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# %%
search_df = pd.read_csv('search_data.csv')
search_df.head()
# Out:
#           project        start  five_year_mark     end_date           handle  \
# 0      Konza tech   2013-01-01      2016-01-01   2020-12-31        konzatech
# 1    Eko Atlantic   2009-01-01      2016-01-01   2020-12-31      EkoAtlantic
# 2  Waterfall City   2006-01-01      2016-01-01   2020-12-31  WaterfallCityZA
# 3       Hope city   2013-01-01      2016-01-01   2020-12-31              NaN
# 4     Vision city   2013-01-01      2016-01-01   2020-12-31    thevisioncity
#
#         country
# 0         Kenya
# 1       Nigeria
# 2  South Africa
# 3         Ghana
# 4        Rwanda

# %%
emotions = ['Anger', 'Anticipation','Disgust','Fear', 'Joy','Sadness', 'Surprise', 'Trust']

# %%
ncr_df = pd.read_csv('ncr_lexicon.csv', sep=';')
ncr_words = ncr_df['English'].tolist()

# %%
for project in search_df['project']:
    df_list = []
    for file in os.listdir('tweets'):
        if file.startswith(project) and file.endswith('_5.csv'):
            df_list.append(pd.read_csv(f'tweets/{file}'))
    super_df = pd.concat(df_list)
    sums = super_df.sum()
    print(project)
    print("-"*20)
    for emotion in emotions:
        print(f'{emotion}: {sums[emotion]}')
    print(super_df['sentiment'].value_counts())
    print()
    
    full_string = ""
    for words in super_df['edited']:
        full_string += f' {words}'
    full_string = full_string.replace("  ", " ")
    
    # get "Hope" count
    if "hope" in project.lower():
        words = full_string.split(" ")
        count = 0
        for word in words:
            if word == "hope":
                count += 1
        print("Hope count:", count)
    
    # Generate a word cloud image
    # get words in NCR word list
    significant_words = []
    for word in full_string.split(" "):
        if word in ncr_words and not(
            ncr_df.loc[ncr_df["English"]==word,emotions[0]].iloc[0] == \
            ncr_df.loc[ncr_df["English"]==word,emotions[1]].iloc[0] == \
            ncr_df.loc[ncr_df["English"]==word,emotions[2]].iloc[0] == \
            ncr_df.loc[ncr_df["English"]==word,emotions[3]].iloc[0] == \
            ncr_df.loc[ncr_df["English"]==word,emotions[4]].iloc[0] == \
            ncr_df.loc[ncr_df["English"]==word,emotions[5]].iloc[0] == \
            ncr_df.loc[ncr_df["English"]==word,emotions[6]].iloc[0] == \
            ncr_df.loc[ncr_df["English"]==word,emotions[7]].iloc[0] == 0
            ):
            significant_words.append(word)
    word_cloud_dict=Counter(significant_words)
    wordcloud = WordCloud(max_font_size=40, background_color="white").generate_from_frequencies(word_cloud_dict)
    # wordcloud = WordCloud(max_font_size=40, background_color="white").generate(full_string)

    # Display the generated image:
    plt.figure(figsize=(16, 10))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
# Out:
# Konza tech
# --------------------
# Anger: 17
# Anticipation: 198
# Disgust: 13
# Fear: 26
# Joy: 79
# Sadness: 18
# Surprise: 51
# Trust: 204
# Positive    163
# Negative     14
# Neutral      13
# Name: sentiment, dtype: int64
# Eko Atlantic
# --------------------
# Anger: 235
# Anticipation: 1077
# Disgust: 190
# Fear: 400
# Joy: 695
# Sadness: 270
# Surprise: 292
# Trust: 1068
# Positive    729
# Neutral     286
# Negative    195
# Name: sentiment, dtype: int64
# Waterfall City
# --------------------
# Anger: 10
# Anticipation: 96
# Disgust: 8
# Fear: 15
# Joy: 49
# Sadness: 23
# Surprise: 20
# Trust: 75
# Positive    60
# Neutral     25
# Negative     8
# Name: sentiment, dtype: int64
# Hope city
# --------------------
# Anger: 25
# Anticipation: 298
# Disgust: 37
# Fear: 29
# Joy: 240
# Sadness: 35
# Surprise: 215
# Trust: 281
# Positive    145
# Negative     22
# Neutral       3
# Name: sentiment, dtype: int64
#
# Hope count: 182
# Vision city
# --------------------
# ...
